# %% [markdown]
# # Rayleigh-Taylor — Python baseline
#
# Thin launcher for `src/python/run.py`. Simulation code lives in `src/`.
# Plotting/animation scripts will live in `scripts/` (TODO).

# %%
# %cd ..

# %%
# !python src/python/run.py \
    --Nx 64 --Ny 128 \
    --steps 200 \
    --scheme rk2 \
    --save-interval 25 \
    --output-dir results/python_run \
    --seed 42 \
    --overwrite
