# %% [markdown]
# # Rayleigh-Taylor — C/CPU baseline
#
# Thin launcher for `src/c/run`. Simulation code lives in `src/c/run.c`.

# %%
# %cd ..

# %%
# !make -C src/c

# %%
# !./src/c/run \
    --Nx 64 --Ny 128 \
    --steps 200 \
    --scheme rk2 \
    --save-interval 25 \
    --output-dir results/c_run \
    --seed 42 \
    --overwrite
