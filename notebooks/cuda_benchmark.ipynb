# %% [markdown]
# # CUDA benchmark
#
# Build the CUDA runner and sweep it across grid sizes, then plot throughput and speedup. Designed to run on Kaggle with a GPU accelerator enabled.

# %%
# !git clone https://github.com/iboudhaine/rayleigh-taylor-instability-simulation.git
# %cd rayleigh-taylor-instability-simulation

# %%
# !nvidia-smi
# !nvcc --version

# %%
# !make -C src/cuda

# %%
# !python scripts/bench.py \
  --impls cuda \
  --grids 128x256,256x512,512x1024,1024x2048 \
  --steps 1000 --warmup-steps 20 --repeats 5 \
  --output results/bench_cuda.csv

# %%
# !python scripts/plot_bench.py --csv results/bench_cuda.csv
