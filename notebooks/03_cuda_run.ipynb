# %% [markdown]
# # Rayleigh-Taylor — CUDA/GPU run (Kaggle)
#
# Thin launcher for `src/cuda/run.cu`. Designed to run on Kaggle (GPU instance).
# Upload this whole repo as a dataset / clone it from GitHub, attach a GPU, and run.

# %%
# %cd ..

# %%
# !nvidia-smi
# !nvcc --version

# %%
# !make -C src/cuda

# %%
# !./src/cuda/run \
    --Nx 512 --Ny 1024 \
    --steps 1000 \
    --scheme rk2 \
    --save-interval 100 \
    --output-dir results/cuda_run \
    --block-x 16 --block-y 16 \
    --seed 42 \
    --overwrite
